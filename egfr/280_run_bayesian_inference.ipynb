# %%
using Serialization, Distributions, AffineInvariantMCMC, StableRNGs 
include("ode_problem.jl")
include("target_probability.jl")
include("define_likelihood_data.jl");

# %% [markdown]
# ### Name Run
#
# run: 280
# test data: pSHC
# augmented: yes
# weighed by AF3 confidence: iptm
# prior offset: +/- 2
# binding prior offset: 0
# different rng

# %%
run = "280"
# Out:
# "200"

# %% [markdown]
# Define Prior Distributions

# %%
#generate bounds for prior
bound_offset = [2,2]
binding_bound_offset = [0,0]
prior_bounds = return_prior_bounds_empirical(bound_offset, binding_bound_offset) #for target probability
prior_distributions = [Uniform(prior_bounds[i]...) for i in 1:length(prior_bounds)];

# %% [markdown]
# Define Test/Train Data

# %%
#first input we need are data points and each point's associated standard deviation to evaluate the likelihood
data_points = deserialize("outputs/000_training_data_w_pshc_test.dict")["response"]
std_dev = deserialize("outputs/000_training_data_w_pshc_test.dict")["average_error"]

#load different EGF ligand dosages needed to simulate all training data
ligand_dosages = return_ligand_dose_order_for_likelihood_w_pshc_test()

#provide function for indexing likelihood data - that is, non test data
training_data_indices = likelihood_w_pshc_test;

# %% [markdown]
# Define ODEProblems for different intial conditions

# %%
#next input we need is an ode problem
odeproblems = []
for egf in ligand_dosages
    odesys, u0, tspan, p = return_ode_problem_default_inputs(egf)
    prob = DifferentialEquations.ODEProblem(odesys, u0, tspan, p) #note p will be overwritten in first run of mcmc algorithm
    push!(odeproblems, prob)
end

# %% [markdown]
# Define ODE Solver Inputs

# %%
#and ode solver inputs, which are consistent for all simulations
odesolver_inputs = return_ode_problem_solver_default_inputs();

# %% [markdown]
# Define Type of ODESolution

# %%
#get type of ODEProblem solution
pred = DifferentialEquations.solve(odeproblems[1], odesolver_inputs["solver"], abstol=odesolver_inputs["abstol"], reltol=odesolver_inputs["reltol"], saveat=odesolver_inputs["saveat"])
ode_sol_type = typeof(pred);

# %% [markdown]
# Define Augmented Likelihood Term

# %%
#also need hyperparameters for augmenting likelihood
augmented_likelihood_parameters = deserialize("outputs/000_augmentation_parameters_predicted_kd_iptm.dict");

# %% [markdown]
# Define Target Distribution for Sampling

# %%
target_probability = parameters -> logprob_augmented(parameters, prior_distributions, data_points, std_dev, training_data_indices, ligand_dosages, odeproblems, odesolver_inputs, ode_sol_type, augmented_likelihood_parameters)
# Out:
# #51 (generic function with 1 method)

# %% [markdown]
# Affine Invariant Sampler Hyperparameters

# %%
#affine invariant sampler hyperparameters
numdims = 50
numwalkers = 1000
thinning = 1
numsamples_perwalker = 1000
burnin = 1000
n_subchains = 70
a_burnin = 4
a = 2
rng = StableRNG(0);

# %% [markdown]
# Run Affine Invariant Sampler from 0

# %%
x0 = Matrix{Float64}(undef,numdims,numwalkers)
for i in 1:numwalkers
    x0[:,i] = [rand(rng, prior_distributions[j]) for j in 1:numdims]
end

chain0, llhoodvals0 = AffineInvariantMCMC.sample(target_probability, numwalkers, x0, burnin, thinning, a_burnin, rng=rng)
serialize("outputs/$(run)_posterior_samples_subchain_0.jls", chain0)
serialize("outputs/$(run)_posterior_samples_likelihood_subchain_0.jls", llhoodvals0)

#release from RAM
chain0 = nothing
llhoodvals0 = nothing

for i in 1:n_subchains
    chain = deserialize("outputs/$(run)_posterior_samples_subchain_$(i-1).jls")
    chain, llhoodvals = AffineInvariantMCMC.sample(target_probability, numwalkers, chain[:, :, end], numsamples_perwalker, thinning, a, rng=rng)
    serialize("outputs/$(run)_posterior_samples_subchain_$(i).jls", chain)
    serialize("outputs/$(run)_posterior_samples_likelihood_subchain_$(i).jls", llhoodvals)
end
# Out:
# ┌ Warning: At t=100.9913051953551, dt was forced below floating point epsilon 1.4210854715202004e-14, and step error estimate = 1.4072647051487341. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=0.055299558613519297, dt was forced below floating point epsilon 6.938893903907228e-18, and step error estimate = 1.40726476778437. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=23.345799805644976, dt was forced below floating point epsilon 3.552713678800501e-15, and step error estimate = 1.407264722255101. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=6.66103071412489, dt was forced below floating point epsilon 8.881784197001252e-16, and step error estimate = 1.4072390157239973. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=42.50563970357391, dt was forced below floating point epsilon 7.105427357601002e-15, and step error estimate = 1.4072206312256839. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=56.799386244992895, dt was forced below floating point epsilon 7.105427357601002e-15, and step error estimate = 1.4072206942891818. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=23.236244900127236, dt was forced below floating point epsilon 3.552713678800501e-15, and step error estimate = 1.399162886119343. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=10.101913882409388, dt was forced below floating point epsilon 1.7763568394002505e-15, and step error estimate = 1.402558057778656. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=2.2354357366861177, dt was forced below floating point epsilon 4.440892098500626e-16, and step error estimate = 1.4057212952546445. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=0.004917184669720883, dt was forced below floating point epsilon 8.673617379884035e-19, and step error estimate = 1.407263241605162. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=0.003302751718848312, dt was forced below floating point epsilon 4.336808689942018e-19, and step error estimate = 1.4072632409388812. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=103.5792359387276, dt was forced below floating point epsilon 1.4210854715202004e-14, and step error estimate = 1.407234737176423. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=0.0008517960477958651, dt was forced below floating point epsilon 1.0842021724855044e-19, and step error estimate = 1.4072647877112878. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=0.002757424119696716, dt was forced below floating point epsilon 4.336808689942018e-19, and step error estimate = 1.407264839081526. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=0.0033299493765577516, dt was forced below floating point epsilon 4.336808689942018e-19, and step error estimate = 1.407264785767872. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=50.196028262547046, dt was forced below floating point epsilon 7.105427357601002e-15, and step error estimate = 1.4072646276035927. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=1.5389481188630247, dt was forced below floating point epsilon 2.220446049250313e-16, and step error estimate = 1.4072647617324983. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=9.09184647996298, dt was forced below floating point epsilon 1.7763568394002505e-15, and step error estimate = 1.4072648249314441. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=6.237183812793364, dt was forced below floating point epsilon 8.881784197001252e-16, and step error estimate = 1.4072647834438519. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=0.7796987101473654, dt was forced below floating point epsilon 1.1102230246251565e-16, and step error estimate = 1.4072648419191953. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=0.008278939365735568, dt was forced below floating point epsilon 1.734723475976807e-18, and step error estimate = 1.4072647552742419. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=0.8675340983908395, dt was forced below floating point epsilon 1.1102230246251565e-16, and step error estimate = 1.4072647788168742. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=42.60408599581099, dt was forced below floating point epsilon 7.105427357601002e-15, and step error estimate = 1.4072647690648825. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t
Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  82%|█████████████████████████████████▋       |  ETA: 0:06:29┌ Warning: At t=5.7050944463295705, dt was forced below floating point epsilon 8.881784197001252e-16, and step error estimate = 1.3213846004981429. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  83%|██████████████████████████████████       |  ETA: 0:06:09┌ Warning: At t=0.1518484839048893, dt was forced below floating point epsilon 2.7755575615628914e-17, and step error estimate = 1.321384593674666. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  84%|██████████████████████████████████▌      |  ETA: 0:05:43┌ Warning: At t=13.333957942718138, dt was forced below floating point epsilon 1.7763568394002505e-15, and step error estimate = 1.321384595203695. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  85%|██████████████████████████████████▊      |  ETA: 0:05:30┌ Warning: At t=1.953281656031915, dt was forced below floating point epsilon 2.220446049250313e-16, and step error estimate = 1.3213845952990249. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  95%|███████████████████████████████████████  |  ETA: 0:01:48┌ Warning: At t=2.08460106311155, dt was forced below floating point epsilon 4.440892098500626e-16, and step error estimate = 1.3213845949164722. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress: 100%|█████████████████████████████████████████| Time: 0:36:08

# %% [markdown]
# Run Affine Invariate Sampler from N Subchain

# %%
#start = 51
#stop = 70
#for i in start:stop
    #chain = deserialize("outputs/$(run)_posterior_samples_subchain_$(i-1).jls")
    #chain, llhoodvals = AffineInvariantMCMC.sample(target_probability, numwalkers, chain[:, :, end], numsamples_perwalker, thinning, a, rng=rng)
    #serialize("outputs/$(run)_posterior_samples_subchain_$(i).jls", chain)
    #serialize("outputs/$(run)_posterior_samples_likelihood_subchain_$(i).jls", llhoodvals)
#end
# Out:
# Progress:   4%|█▌                                       |  ETA: 0:35:06┌ Warning: At t=0.7235420902632596, dt was forced below floating point epsilon 1.1102230246251565e-16, and step error estimate = 1.3213845949770795. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=2.2749291839570533, dt was forced below floating point epsilon 4.440892098500626e-16, and step error estimate = 1.3213845951947794. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=7.723957208811436, dt was forced below floating point epsilon 8.881784197001252e-16, and step error estimate = 1.321384595495505. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=1.952530946968742, dt was forced below floating point epsilon 2.220446049250313e-16, and step error estimate = 1.321384593893071. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:   4%|█▋                                       |  ETA: 0:35:08┌ Warning: At t=2.1550098130285744, dt was forced below floating point epsilon 4.440892098500626e-16, and step error estimate = 1.3213845824194799. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:   7%|██▉                                      |  ETA: 0:33:37┌ Warning: At t=2.977660909855116, dt was forced below floating point epsilon 4.440892098500626e-16, and step error estimate = 1.3213845196016867. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:   9%|███▋                                     |  ETA: 0:32:53┌ Warning: At t=0.5754903664410241, dt was forced below floating point epsilon 1.1102230246251565e-16, and step error estimate = 1.3213845943009201. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  10%|████▏                                    |  ETA: 0:32:17┌ Warning: At t=78.63520751610473, dt was forced below floating point epsilon 1.4210854715202004e-14, and step error estimate = 1.321384598090206. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  16%|██████▌                                  |  ETA: 0:30:06┌ Warning: At t=0.25844642230928233, dt was forced below floating point epsilon 5.551115123125783e-17, and step error estimate = 1.3213844578490896. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  17%|██████▉                                  |  ETA: 0:29:46┌ Warning: At t=1.769997282010935, dt was forced below floating point epsilon 2.220446049250313e-16, and step error estimate = 1.321384595027618. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:
Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:   3%|█▏                                       |  ETA: 0:34:33┌ Warning: At t=66.60018494761253, dt was forced below floating point epsilon 1.4210854715202004e-14, and step error estimate = 1.3213845964956197. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:   4%|█▌                                       |  ETA: 0:34:10┌ Warning: At t=0.08315884113690632, dt was forced below floating point epsilon 1.3877787807814457e-17, and step error estimate = 1.3213845945041602. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:   5%|██                                       |  ETA: 0:33:42┌ Warning: At t=1.7288883351595774, dt was forced below floating point epsilon 2.220446049250313e-16, and step error estimate = 1.3213845949222147. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:   8%|███▍                                     |  ETA: 0:32:27┌ Warning: At t=7.838530173541361, dt was forced below floating point epsilon 8.881784197001252e-16, and step error estimate = 1.270383808081991. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:   9%|███▊                                     |  ETA: 0:32:07┌ Warning: At t=0.14381654175561853, dt was forced below floating point epsilon 2.7755575615628914e-17, and step error estimate = 1.3213845659311478. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  10%|███▉                                     |  ETA: 0:31:54┌ Warning: At t=77.76004298498805, dt was forced below floating point epsilon 1.4210854715202004e-14, and step error estimate = 1.3213846551755926. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  10%|████▎                                    |  ETA: 0:31:35┌ Warning: At t=1.2058845764713257, dt was forced below floating point epsilon 2.220446049250313e-16, and step error estimate = 1.3213845939504747. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=1.6980429015253744, dt was forced below floating point epsilon 2.220446049250313e-16, and step error estimate = 1.3213845939746345. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  13%|█████▍                                   |  ETA: 0:30:41┌ Warning: At t=0.2731868353835776, dt was forced below floating point epsilon 5.551115123125783e-17, and step error estimate = 1.3213845948634029. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  20%|████████▎                                |  ETA: 0:28:14┌ Warning: At t=0.9700371590282447, dt was forced below floating point epsilon 1.1102230246251565e-16, and step error estimate = 1.3213845944043907. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  22%|█████████▎                               |  ETA: 0:27:22┌ Warning: At t=0.7313863991747788, dt was forced below floating point epsilon 1.1102230246251565e-16, and step error estimate = 1.3213845942700138. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  25%|██████████▎                              |  ETA: 0:26:31┌ Warning: At t=10.92726065159017, dt was forced below floating point epsilon 1.7763568394002505e-15, and step error estimate = 1.321384596423682. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=7.936815685173576, dt was forced below floating point epsilon 8.881784197001252e-16, and step error estimate = 1.3213845797049726. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  26%|██████████▉                              |  ETA: 0:25:59┌ Warning: At t=0.15129227189846092, dt was forced below floating point epsilon 2.7755575615628914e-17, and step error estimate = 1.3213845946722143. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  28%|███████████▋                             |  ETA: 0:25:15┌ Warning: At t=1.908674210936046, dt was forced below floating point epsilon 2.220446049250313e-16, and step error estimate = 1.3213823009624877. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  31%|████████████▌                            |  ETA: 0:24:30┌ Warning: At t=56.72236852658198, dt was forced below floating point epsilon 7.105427357601002e-15, and step error estimate = 1.32138459422853. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  31%|████████████▋                            |  ETA: 0:24:24┌ Warning: At t=13.016755132202444, dt was forced below floating point epsilon 1.7763568394002505e-15, and step error estimate = 1.3213843169181245. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=53.31264349072597, dt was forced below floating point epsilon 7.105427357601002e-15, and step error estimate = 1.3213845927460683. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  32%|█████████████                            |  ETA: 0:24:05┌ Warning: At t=0.18956413350786472, dt was forced below floating point epsilon 2.7755575615628914e-17, and step error estimate = 1.3213845947069034. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:
Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  75%|██████████████████████████████▉          |  ETA: 0:08:44┌ Warning: At t=11.639556234470152, dt was forced below floating point epsilon 1.7763568394002505e-15, and step error estimate = 1.3213845955690522. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  76%|███████████████████████████████          |  ETA: 0:08:37┌ Warning: At t=8.617932752194355, dt was forced below floating point epsilon 1.7763568394002505e-15, and step error estimate = 1.3213845979402912. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=1.1954553212083843, dt was forced below floating point epsilon 2.220446049250313e-16, and step error estimate = 1.3213845944455427. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=5.379205727447812, dt was forced below floating point epsilon 8.881784197001252e-16, and step error estimate = 1.3213845947219107. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  77%|███████████████████████████████▋         |  ETA: 0:08:05┌ Warning: At t=1.0311023921233438, dt was forced below floating point epsilon 2.220446049250313e-16, and step error estimate = 1.321384591853152. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  79%|████████████████████████████████▎        |  ETA: 0:07:34┌ Warning: At t=2.1576724446828592, dt was forced below floating point epsilon 4.440892098500626e-16, and step error estimate = 1.3213845725316131. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  80%|████████████████████████████████▊        |  ETA: 0:07:08┌ Warning: At t=0.9262560934268433, dt was forced below floating point epsilon 1.1102230246251565e-16, and step error estimate = 1.3213845947096654. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  84%|██████████████████████████████████▌      |  ETA: 0:05:39┌ Warning: At t=1.0177551918849268, dt was forced below floating point epsilon 2.220446049250313e-16, and step error estimate = 1.3213845831467106. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=1.5297692105533678, dt was forced below floating point epsilon 2.220446049250313e-16, and step error estimate = 1.3213845831290125. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=4.712009626127635, dt was forced below floating point epsilon 8.881784197001252e-16, and step error estimate = 1.3213845837389357. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  92%|█████████████████████████████████████▋   |  ETA: 0:02:54┌ Warning: At t=5.266391274448537, dt was forced below floating point epsilon 8.881784197001252e-16, and step error estimate = 1.3213845340681272. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  92%|█████████████████████████████████████▊   |  ETA: 0:02:48┌ Warning: At t=20.590684923986753, dt was forced below floating point epsilon 3.552713678800501e-15, and step error estimate = 1.3213845952736172. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  93%|██████████████████████████████████████▎  |  ETA: 0:02:22┌ Warning: At t=3.0443037970188356, dt was forced below floating point epsilon 4.440892098500626e-16, and step error estimate = 1.3213845955559296. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=0.4300232564777158, dt was forced below floating point epsilon 5.551115123125783e-17, and step error estimate = 1.321384594991609. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=0.4376332499843713, dt was forced below floating point epsilon 5.551115123125783e-17, and step error estimate = 1.321384592785484. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  94%|██████████████████████████████████████▌  |  ETA: 0:02:09┌ Warning: At t=4.233129795734821, dt was forced below floating point epsilon 8.881784197001252e-16, and step error estimate = 1.3213845924875023. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  96%|███████████████████████████████████████▎ |  ETA: 0:01:31┌ Warning: At t=1.0307249135452738, dt was forced below floating point epsilon 2.220446049250313e-16, and step error estimate = 1.3213845949329235. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  98%|████████████████████████████████████████▍|  ETA: 0:00:34┌ Warning: At t=12.855098398184602, dt was forced below floating point epsilon 1.7763568394002505e-15, and step error estimate = 1.321384595442538. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress: 100%|█████████████████████████████████████████| Time: 0:35:20
# Progress:   7%|██▉                                      |  ETA: 0:33:00┌ Warning: At t=2.5049108010086645, dt was forced below floating point epsilon 4.440892098500626e-16, and step error estimate = 1.3213845940335385. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  12%|████▊                                    |  ETA: 0:31:16┌ Warning: At t=1.0736379094594672, dt was forced below floating point epsilon 2.220446049250313e-16, and step error estimate = 1.3213845950753478. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=2.359156272977947, dt was forced below floating point epsilon 4.440892098500626e-16, and step error estimate = 1.3213845951140548. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  12%|████▉                                    |  ETA: 0:31:09┌ Warning: At t=13.295154256002037, dt was forced below floating point epsilon 1.7763568394002505e-15, and step error estimate = 1.3213845952072636. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# ...
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress: 100%|█████████████████████████████████████████| Time: 0:36:07
# Progress:   0%|▏                                        |  ETA: 0:36:09┌ Warning: At t=13.761570770150337, dt was forced below floating point epsilon 1.7763568394002505e-15, and step error estimate = 1.321384595302152. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:   2%|█                                        |  ETA: 0:35:17┌ Warning: At t=1.2793399115540316, dt was forced below floating point epsilon 2.220446049250313e-16, and step error estimate = 1.321384594897957. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:   6%|██▌                                      |  ETA: 0:34:04┌ Warning: At t=0.5986539157369206, dt was forced below floating point epsilon 1.1102230246251565e-16, and step error estimate = 1.3213845948071772. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  10%|████                                     |  ETA: 0:32:23┌ Warning: At t=0.402565799507308, dt was forced below floating point epsilon 5.551115123125783e-17, and step error estimate = 1.321384025233085. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  13%|█████▎                                   |  ETA: 0:31:12┌ Warning: At t=0.6188256688710013, dt was forced below floating point epsilon 1.1102230246251565e-16, and step error estimate = 1.32138459508783. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  16%|██████▍                                  |  ETA: 0:30:07┌ Warning: At t=0.6259285777410145, dt was forced below floating point epsilon 1.1102230246251565e-16, and step error estimate = 1.3213845943904312. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  25%|██████████▏                              |  ETA: 0:26:46┌ Warning: At t=1.1614037738493082, dt was forced below floating point epsilon 2.220446049250313e-16, and step error estimate = 1.321384594728086. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  38%|███████████████▊                         |  ETA: 0:21:43┌ Warning: At t=0.14241529162528832, dt was forced below floating point epsilon 2.7755575615628914e-17, and step error estimate = 1.3213845943639344. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  40%|████████████████▋                        |  ETA: 0:20:57┌ Warning: At t=29.0177139401263, dt was forced below floating point epsilon 3.552713678800501e-15, and step error estimate = 1.3213845964226112. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  41%|████████████████▉                        |  ETA: 0:20:45┌ Warning: At t=1.2896671571570097, dt was forced below floating point epsilon 2.220446049250313e-16, and step error estimate = 1.321383728005157. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  49%|████████████████████▎                    |  ETA: 0:17:49┌ Warning: At t=0.2069780039863482, dt was forced below floating point epsilon 2.7755575615628914e-17, and step error estimate = 1.321384593550766. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  51%|█████████████████████                    |  ETA: 0:17:11┌ Warning: At t=3.7538301414195594, dt was forced below floating point epsilon 4.440892098500626e-16, and step error estimate = 1.3213845866169802. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=0.8915398709434715, dt was forced below floating point epsilon 1.1102230246251565e-16, and step error estimate = 1.3213845940888234. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  60%|████████████████████████▊                |  ETA: 0:13:54┌ Warning: At t=0.37630194723147736, dt was forced below floating point epsilon 5.551115123125783e-17, and step error estimate = 1.3213845946994929. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=0.5834742632171812, dt was forced below floating point epsilon 1.1102230246251565e-16, and step error estimate = 1.321384594744985. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  64%|██████████████████████████               |  ETA: 0:12:51┌ Warning: At t=0.34878679601115936, dt was forced below floating point epsilon 5.551115123125783e-17, and step error estimate = 1.321384594936936. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  66%|███████████████████████████              |  ETA: 0:12:00┌ Warning: At t=1.0567955951491426, dt was forced below floating point epsilon 2.220446049250313e-16, and step error estimate = 1.321384595078929. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  66%|███████████████████████████▏             |  ETA: 0:11:53┌ Warning: At t=0.45016779418368086, dt was forced below floating point epsilon 5.551115123125783e-17, and step error estimate = 1.321384594916327. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=1.3685195652566817, dt was forced below floating point epsilon 2.220446049250313e-16, and step error estimate = 1.3213845950536385. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  70%|████████████████████████████▊            |  ETA: 0:10:31┌ Warning: At t=0.738745412941063, dt was forced below floating point epsilon 1.1102230246251565e-16, and step error estimate = 1.3213845944887468. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=1.6717784191473224, dt was forced below floating point epsilon 2.220446049250313e-16, and step error estimate = 1.321384594483623. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  75%|██████████████████████████████▋          |  ETA: 0:08:56┌ Warning: At t=0.18154947501958754, dt was forced below floating point epsilon 2.7755575615628914e-17, and step error estimate = 1.3213845920216973. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  77%|███████████████████████████████▊         |  ETA: 0:07:59┌ Warning: At t=3.9168036613462593, dt was forced below floating point epsilon 4.440892098500626e-16, and step error estimate = 1.4072647545123784. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  79%|████████████████████████████████▍        |  ETA: 0:07:21┌ Warning: At t=3.5510142756720544, dt was forced below floating point epsilon 4.440892098500626e-16, and step error estimate = 1.3213845954197252. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  83%|██████████████████████████████████       |  ETA: 0:05:58┌ Warning: At t=9.867187524137716, dt was forced below floating point epsilon 1.7763568394002505e-15, and step error estimate = 1.3213845952089853. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=0.11409183997044171, dt was forced below floating point epsilon 1.3877787807814457e-17, and step error estimate = 1.3213845949355223. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=0.2687038004942471, dt was forced below floating point epsilon 5.551115123125783e-17, and step error estimate = 1.3213845950035816. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  87%|███████████████████████████████████▌     |  ETA: 0:04:42┌ Warning: At t=2.535325049664983, dt was forced below floating point epsilon 4.440892098500626e-16, and step error estimate = 1.3213845955086991. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  87%|███████████████████████████████████▋     |  ETA: 0:04:36┌ Warning: At t=0.975719620694526, dt was forced below floating point epsilon 1.1102230246251565e-16, and step error estimate = 1.321384594431257. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  88%|███████████████████████████████████▉     |  ETA: 0:04:23┌ Warning: At t=0.41810295569154143, dt was forced below floating point epsilon 5.551115123125783e-17, and step error estimate = 1.3213845868592913. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  90%|█████████████████████████████████████▏   |  ETA: 0:03:20┌ Warning: At t=83.00636610835394, dt was forced below floating point epsilon 1.4210854715202004e-14, and step error estimate = 1.3213846021703852. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  94%|██████████████████████████████████████▌  |  ETA: 0:02:11┌ Warning: At t=0.16201790746664865, dt was forced below floating point epsilon 2.7755575615628914e-17, and step error estimate = 1.3213845930246908. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  98%|████████████████████████████████████████▎|  ETA: 0:00:36┌ Warning: At t=18.393517023538514, dt was forced below floating point epsilon 3.552713678800501e-15, and step error estimate = 1.3213845952987002. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  99%|████████████████████████████████████████▊|  ETA: 0:00:11┌ Warning: At t=4.842840824177188, dt was forced below floating point epsilon 8.881784197001252e-16, and step error estimate = 1.321384592227707. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress: 100%|█████████████████████████████████████████| Time: 0:35:03
